# %% [markdown]
# ### Dataverwerking sterrenkundeproef
#
# Deze notebook is een **tool** bij het analyseren van de data. Dit is **geen** vervanging voor de instructies in de practicumhandleiding. Sterker nog, de handleiding bevat hints die hier niet genoemd zijn. Lees deze dus zeker goed door!
#
# ## Laden van packages
#
# Als een package nog niet geïnstalleerd is, kun je dit doen door de **anaconda prompt** te openen en de volgende command uit te voeren:
#
# ```
# pip install <package>
# ```
#
# waarbij je ```<package>``` verandert door de te installeren package.

# %% [markdown]
# # Dataverwerking sterrenkundeproef
#
# Deze notebook is een **tool** bij het analyseren van de data. Dit is **geen** vervanging voor de instructies in de practicumhandleiding. Sterker nog, de handleiding bevat hints die hier niet genoemd zijn. Lees deze dus zeker goed door!
#
# ## Laden van packages
#
# Als een package nog niet geïnstalleerd is, kun je dit doen door de **anaconda prompt** te openen en de volgende command uit te voeren:
#
# ```
# pip install <package>
# ```
#
# waarbij je ```<package>``` verandert door de te installeren package.

# %%
# Standaard Python bibliotheek
import glob

# Te Installeren
import astropy.io.fits as pf
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt

from astropy import constants as const
# Out:
# ERROR: No token list is defined
# ---------------------------------------------------------------------------
# YaccError                                 Traceback (most recent call last)
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/core.py:2070, in _UnitMetaClass.__call__(cls, s, represents, format, namespace, doc, parse_strict)
#    2063     with (
#    2064         _WARNING_LOCK,
#    2065         warnings.catch_warnings(
#    (...)   2068         ),
#    2069     ):
# -> 2070         return f.parse(s)
#    2071 except NotImplementedError:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/format/generic.py:501, in Generic.parse(cls, s, debug)
#     499     s = cls._regex_superscript.sub(cls._convert_superscript, s)
# --> 501 result = cls._do_parse(s, debug)
#     503 # Check for excess solidi, but exclude fractional exponents (accepted)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/format/base.py:225, in _ParsingFormatMixin._do_parse(cls, s, debug)
#     224 try:
# --> 225     return cls._parser.parse(s, lexer=cls._lexer, debug=debug)
#     226 except ValueError as e:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/utils/decorators.py:859, in classproperty.__get__(self, obj, objtype)
#     858 if val is _NotFound:
# --> 859     val = self.fget.__wrapped__(objtype)
#     860     self._cache[objtype] = val
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/format/generic.py:398, in _GenericParserMixin._parser(cls)
#     396     raise ValueError()
# --> 398 return parsing.yacc(tabmodule="generic_parsetab", package="astropy/units")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/utils/parsing.py:138, in yacc(tabmodule, package)
#     137 with _LOCK, _patch_ply_module(yacc, caller_dir / (tabmodule + ".py"), package):
# --> 138     parser = yacc.yacc(
#     139         tabmodule=tabmodule,
#     140         outputdir=caller_dir,
#     141         debug=False,
#     142         optimize=True,
#     143         write_tables=True,
#     144     )
#     145 return ThreadSafeParser(parser)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/extern/ply/yacc.py:3282, in yacc(method, debug, module, tabmodule, start, check_recursion, optimize, write_tables, debugfile, outputdir, debuglog, errorlog, picklefile)
#    3281 if pinfo.error:
# -> 3282     raise YaccError('Unable to build parser')
#    3284 # Check signature against table files (if any)
#
# YaccError: Unable to build parser
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 10
#       7 from scipy import interpolate
#       8 import matplotlib.pyplot as plt
# ---> 10 from astropy import constants as const
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/__init__.py:55, in __getattr__(attr)
#      52 if attr in __all__:
#      53     from importlib import import_module
# ---> 55     return import_module("astropy." + attr)
#      57 raise AttributeError(f"module 'astropy' has no attribute {attr!r}")
#
# File /usr/local/python/3.12.1/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/constants/__init__.py:23
#      19 from astropy.utils import find_current_module
#      21 # Hack to make circular imports with units work
#      22 # isort: split
# ---> 23 from astropy import units
#      25 del units
#      27 from . import cgs, si
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/__init__.py:55, in __getattr__(attr)
#      52 if attr in __all__:
#      53     from importlib import import_module
# ---> 55     return import_module("astropy." + attr)
#      57 raise AttributeError(f"module 'astropy' has no attribute {attr!r}")
#
# File /usr/local/python/3.12.1/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/__init__.py:13
#       1 # Licensed under a 3-clause BSD style license - see LICENSE.rst
#       3 """
#       4 This subpackage contains classes and functions for defining and converting
#       5 between different physical units, as well as the units themselves.
#    (...)     10 code under a BSD license.
#      11 """
# ---> 13 from . import (
#      14     astrophys,
#      15     cgs,
#      16     core,
#      17     decorators,
#      18     errors,
#      19     imperial,
#      20     misc,
#      21     photometric,
#      22     physical,
#      23     quantity,
#      24     required_by_vounit,
#      25     si,
#      26     structured,
#      27 )
#      28 from .astrophys import *
#      29 from .cgs import *
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/astrophys.py:71
#      51 def_unit(
#      52     ["jupiterRad", "R_jup", "Rjup", "R_jupiter", "Rjupiter"],
#      53     _si.R_jup,
#    (...)     58     format={"latex": r"R_{\rm J}", "unicode": "R\N{JUPITER}"},
#      59 )
#      60 def_unit(
#      61     ["earthRad", "R_earth", "Rearth"],
#      62     _si.R_earth,
#    (...)     67     format={"latex": r"R_{\oplus}", "unicode": "R⊕"},
#      68 )
#      69 def_unit(
#      70     ["lyr", "lightyear"],
# ---> 71     (_si.c * si.yr).to(si.m),
#      72     namespace=_ns,
#      73     prefixes=True,
#      74     doc="Light year",
#      75 )
#      76 def_unit(
#      77     ["lsec", "lightsecond"],
#      78     (_si.c * si.s).to(si.m),
#    (...)     81     doc="Light second",
#      82 )
#      85 ###########################################################################
#      86 # MASS
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/constants/constant.py:43, in ConstantMeta.__new__.<locals>.wrap.<locals>.wrapper(self, *args, **kwargs)
#      41 for inst in instances.values():
#      42     try:
# ---> 43         self.unit.to(inst.unit)
#      44     except UnitsError:
#      45         self._has_incompatible_units.add(name_lower)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/quantity.py:996, in Quantity.unit(self)
#     990 @property
#     991 def unit(self):
#     992     """
#     993     A `~astropy.units.UnitBase` object representing the unit of this
#     994     quantity.
#     995     """
# --> 996     return self._unit
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/utils/decorators.py:949, in lazyproperty.__get__(self, obj, owner)
#     947         val = obj_dict.get(self._key, _NotFound)
#     948         if val is _NotFound:
# --> 949             val = self.fget(obj)
#     950             obj_dict[self._key] = val
#     951 return val
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/constants/constant.py:209, in Constant._unit(self)
#     206 @lazyproperty
#     207 def _unit(self):
#     208     """The unit(s) in which this constant is defined."""
# --> 209     return Unit(self._unit_string)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/astropy/units/core.py:2101, in _UnitMetaClass.__call__(cls, s, represents, format, namespace, doc, parse_strict)
#    2091     msg = (
#    2092         f"'{s}' did not parse as {format_clause}unit: {str(e)} "
#    2093         "If this is meant to be a custom unit, "
#    (...)   2098         "https://docs.astropy.org/en/latest/units/combining_and_defining.html"
#    2099     )
#    2100     if parse_strict == "raise":
# -> 2101         raise ValueError(msg)
#    2102     warnings.warn(msg, UnitsWarning)
#    2103 return UnrecognizedUnit(s)
#
# ValueError: 'm / (s)' did not parse as unit: Unable to build parser If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html

# %% [markdown]
# ## Voorbereiding
#
# Om een goed gevoel te krijgen voor de data is het handig om eerst de snelheid uit één van de spectra te bepalen. Op die manier krijg je al een idee van je strategie en raak je straks niet verdwaald in de grote hoeveelheid data.
#
# Zorg zeker ook dat je de data goed begrijpt voordat je aan de analyse begint: **welke info heb je en wat wil je hiermee bereiken?**
#
# ### Data laden
#
# Om te beginnen moet je de spectra inladen. Je hebt een map gekregen met een specifieke naam, namelijk de sternaam. In deze map zitten spectrale gegevens en een txt.bestand (LijnLijst.txt). Sla deze notebook op dezelfde plek op als die map. Dan kan je met volgende code je spectra inlezen.

# %%
sternaam = 'BD-11_162' # Vul hier de naam van de ster in

# Maak een lijst van alle spectra. Data is in FITS format
datalist = glob.glob("%s/*.fits" %sternaam)
datalist.sort()
#print(datalist)


# Inlezen van de spectrale lijnen. De goflengte is in rust en in lucht (niet vacuum)
inputfile = "%s/LijnLijst.txt" %sternaam
lines,weights = np.loadtxt(inputfile,usecols=(0,1),unpack=True)

# %%
# Neem een willekeurig spectrum als voorbeeld
# Spec = intensiteit
# Header laadt de metadata in (o.a. wie de waarnemer was, datum van de observatie...)
spec = pf.getdata(datalist[2])
header = pf.getheader(datalist[2])

# %% [markdown]
# ### Bereid de datastructuur voor
#
# - Inlezen van de meta-data uit header
# - Aanmaken van een golflengtegrid
#
# - **Extra**: Ga voor jezelf na hoe de golflengtegrid wordt aangemaakt

# %%
def golflengte_grid(spec, header):

    # Lees meta-data
    ref_pix = int(header['CRPIX1'])-1   # index van de referentiepixel
    ref_val = float(header['CRVAL1'])   # ln(golflengte) van de referentiepixel
    ref_del = float(header['CDELT1'])   # breedte van de pixel in eenheid van CRVAL1
    JD = header['BJD']  # datum van de waarneming in Juliaanse dagen
    unitx = header['CTYPE1']

    numberpoints = spec.shape[0]

    # Maak een golflengtegrid aan
    wavelengthbegin = ref_val - ref_pix*ref_del
    wavelengthend = wavelengthbegin + (numberpoints-1)*ref_del
    wavelengths = np.linspace(wavelengthbegin,wavelengthend,numberpoints)
    wavelengths = np.exp(wavelengths)

    return wavelengths, JD, unitx


wavelengths, JD, unitx = golflengte_grid(spec, header)

# %% [markdown]
# ### Maak een figuur: intensiteit vs. golflengte
#
# - Welke kenmerken zie je en wat betekenen zij fysisch?
# - Bestudeer ook ```LijnLijst.txt```. Welke data is gegeven in de kolommen? Wat stelt deze data voor? Wat is de relatie tussen LijnLijst.txt en de plot?
#
# - **Extra**: Denk alvast na over hoe je de radiale snelheid uit deze gegevens kan bepalen.

# %%
figalle, allg = plt.subplots()


# begin, einde = 1000, 1650
# llg.plot(wavelengths[begin:einde], spec[begin:einde])
allg.plot(wavelengths, spec)

allg.set_ylabel("intensiteit (flux)")
allg.set_xlabel(r"golflengte")
plt.tight_layout()
plt.show()
#plt.savefig('Spectrum.png')

# %% [raw]
# llfig, llg = plt.subplots()
# llg.plot(lines, weights)
#
# llg.set_ylabel("intensiteit (flux)")
# llg.set_xlabel("golflengte")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Opgaven
#
# ### Definieer een functie om de radiale snelheid te bepalen
#
# - Test de functie op de voorbeeld data uit de voorbereiding
# - Laat in een figuur zien hoe je deze radiale snelheid hebt bepaald

# %%
file = "00307959_HRF_OBJ_ext_CosmicsRemoved_log_merged_cf"
vbfile = "%s/00307959_HRF_OBJ_ext_CosmicsRemoved_log_merged_cf.fits" %sternaam

vbdatalist = glob.glob(vbfile)
vbdatalist.sort()
vbspec = pf.getdata(vbdatalist[0])
vbheader = pf.getheader(vbdatalist[0])

vbwl, vbJD, vbunitx = golflengte_grid(vbspec, vbheader)

# %%
vbfig, vbllg = plt.subplots()

vbllg.plot(vbwl, vbspec)
plt.show()

# %% [markdown]
# #### Radiale snelheid
#
# - Bereken op dezelfde manier de radiale snelheid voor alle spectra die je hebt gekregen
# - Kijk ook naar de datum waarop elk spectrum is opgemeten: header['BJD']

# %% [markdown]
# #### Figuur
#
# Je weet nu hoe de radiale snelheid verandert in de tijd
#
# - Plot de radiale snelheid als een functie van de observatietijdstipppen
# - Als je de tijdsas op 0 wil laten beginnen mag dat (de start van de Juliaanse kalender is niet de start van de waarneming)

# %%
#plt.savefig('V_versus_t_%s.png' %sternaam)

# %% [markdown]
# ### Bepaal de periode
#
# - Schat vanuit de figuur de amplitude en periode van de radiale snelheid

# %% [markdown]
# ### Bepaal de massafunctie

# %% [markdown]
# ### Massafunctie bespreken
#
# Aan het einde van de vorige sectie heb je een waarde voor de massafunctie bepaald. In het laatste onderdeel van dit practicum ga je deze massafunctie verder bespreken

# %% [markdown]
# #### Los de massafunctie op voor $m_{2}$
#
# - Los de massafunctie op voor $m_{2}$ voor verschillende inclinaties (zie de practicumhandleiding)

# %% [markdown]
# #### Figuur
#
# - Plot $m_{2}(i)$ voor de gevonden massafunctie

# %%
#plt.savefig('Massafunctieoplossing_%s.png' % sternaam)
